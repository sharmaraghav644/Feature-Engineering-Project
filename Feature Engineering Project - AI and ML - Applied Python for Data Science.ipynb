# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Specify the file path
file_path = "/Users/raghavsharma/desktop/PEP1.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

#print(df)

# %%
# Get the shape of the DataFrame
df_shape = df.shape

# Print the shape
print("Shape of the DataFrame: ", df_shape) #(rows,columns)
# Out:
# Shape of the DataFrame:  (1460, 81)

# %%
#printing the null values in the DataFrame
nullValues=pd.isnull(df)
print(nullValues)

sumNumValues=pd.isnull(df).sum()
print(sumNumValues)

columnsOfNullValues = nullValues[nullValues > 0].index 
print(columnsOfNullValues)

# %%
# Calculate the number of unique values for each column
uniqueValues = df.nunique()

# Filter the columns with unique values
columnsWithUniques = uniqueValues[uniqueValues == len(df)].index

# Print the columns with unique values
print("Columns with unique values:")
print(columnsWithUniques)

# %%
# Separate numerical and categorical variables into further datasets
numericalVariables = df.select_dtypes(include=['int64', 'float64'])
categorical_variables = df.select_dtypes(include=['object'])


# Save numerical variables as CSV
numericalVariables.to_csv('numericaVariables.csv', index=False)

# Save categorical variables as CSV
categoricalVariables.to_csv('categorical_variables.csv', index=False)


# Print the numerical variables dataset
print("Numerical Variables:")
print(numericalVariables)

# Print the categorical variables dataset
print("Categorical Variables:")
print(categorical_variables)
# Out:
# Categorical Variables:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 1455       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
# ...

# %%
df1=pd.read_csv("numericaVariables.csv")


#EDM for Numberical Variables Dataset
#1) Dropping missing values - we can use dropna() for this:

dropMissingValues=df1.dropna()
print(dropMissingValues)

#2)Filling missing values - we can use fillna() for this:

fillMissingValues=df1.fillna(0) #we can also fill the missing values using the mean, median or mode. For example

fillMissingValues1=df1.fillna(df.mode())
print(fillMissingValues) #both are printed for examplatory purposes
print(fillMissingValues1)
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  \
# ...

# %%
#3 - Forward fill and backward fill

# Fill missing values with a specific value
dfForwardFilled = df1.fillna('Unknown') #filling the missing values with 'Unknown'

# Backward fill (bfill) missing values
dfBackwardFilled = df1.bfill()

# Print the filled DataFrame
print("Filled DataFrame:")
print(dfForwardFilled)

# Print the DataFrame with backward-filled missing values
print("Backward-filled DataFrame:")
print(dfBackwardFilled)
# Out:
# Backward-filled DataFrame:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave  Grvl      Reg
# 1        2          20       RL         80.0     9600   Pave  Grvl      Reg
# 2        3          60       RL         68.0    11250   Pave  Grvl      IR1
# 3        4          70       RL         60.0     9550   Pave  Grvl      IR1
# 4        5          60       RL         84.0    14260   Pave  Grvl      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
#Interpolate method


# Interpolate missing values
dfInterpolated1 = df1.interpolate() #fill the missing values based on the linear interpolation

# Print the interpolated DataFrame
print("Interpolated DataFrame:")
print(dfInterpolated1)
# Out:
# Interpolated DataFrame:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  \
# ...

# %%
#Masking

# Filter rows with missing values
missingValues1 = df1[df1.isnull()]

# Print the filtered DataFrame
print("Rows with Missing Values:")
print(missingValues1)
# Out:
# Rows with Missing Values:
#       Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0    NaN         NaN          NaN      NaN          NaN          NaN
# 1    NaN         NaN          NaN      NaN          NaN          NaN
# 2    NaN         NaN          NaN      NaN          NaN          NaN
# 3    NaN         NaN          NaN      NaN          NaN          NaN
# 4    NaN         NaN          NaN      NaN          NaN          NaN
# ...   ..         ...          ...      ...          ...          ...
# 1455 NaN         NaN          NaN      NaN          NaN          NaN
# 1456 NaN         NaN          NaN      NaN          NaN          NaN
# 1457 NaN         NaN          NaN      NaN          NaN          NaN
# 1458 NaN         NaN          NaN      NaN          NaN          NaN
# 1459 NaN         NaN          NaN      NaN          NaN          NaN
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  \
# ...

# %%
#Skewness and distribution of the dataset

skewness = df1.skew()
#print("Skewness:")
#print(skewness)
# Out:
# Skewness:
# Id                0.000000
# MSSubClass        1.407657
# LotFrontage       2.163569
# LotArea          12.207688
# OverallQual       0.216944
# OverallCond       0.693067
# YearBuilt        -0.613461
# YearRemodAdd     -0.503562
# MasVnrArea        2.669084
# BsmtFinSF1        1.685503
# BsmtFinSF2        4.255261
# BsmtUnfSF         0.920268
# TotalBsmtSF       1.524255
# 1stFlrSF          1.376757
# 2ndFlrSF          0.813030
# LowQualFinSF      9.011341
# GrLivArea         1.366560
# BsmtFullBath      0.596067
# BsmtHalfBath      4.103403
# FullBath          0.036562
# HalfBath          0.675897
# Bedroom           0.211790
# Kitchen           4.488397
# TotRmsAbvGrd      0.676341
# Fireplaces        0.649565
# GarageYrBlt      -0.649415
# GarageCars       -0.342549
# GarageArea        0.179981
# WoodDeckSF        1.541376
# OpenPorchSF       2.364342
# EnclosedPorch     3.089872
# 3SsnPorch        10.304342
# ScreenPorch       4.122214
# PoolArea         14.828374
# ...

# %%
#Distribution of the dataset - Numerical Values

numericalVariables = df1.select_dtypes(include=['int64', 'float64'])

# Calculate the distribution
distribution = numericalVariables.describe()

# Print the distribution statistics
print("Distribution:")
print(distribution)
# Out:
# Distribution:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# ...

# %%
#Significant variable using Corelation matrix

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

numericalVariables = df1.select_dtypes(include=['int64', 'float64'])

# Calculate correlation matrix
correlationMatrix = numericalVariables.corr()
#print(correlationMatrix)

# Assuming you have calculated the correlation matrix and stored it in correlationMatrix

# Set the threshold for significance
correlation_threshold = 0.5

# Identify the significant variables
significantNumericalVariables = []
for column in correlationMatrix:
    correlated_columns = correlationMatrix[correlationMatrix[column] > correlation_threshold].index.tolist()
    correlated_columns.remove(column)  # Remove self-correlation
    significantNumericalVariables.extend(correlated_columns)

# Remove duplicates and sort the list
significantNumericalVariables = sorted(list(set(significantNumericalVariables)))

# Print the significant variables
print("Significant Variables:")
for variable in significantNumericalVariables:
    print(variable)

# Plot correlation matrix heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlationMatrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# Significant Variables:
# 1stFlrSF
# 2ndFlrSF
# Bedroom
# BsmtFinSF1
# BsmtFullBath
# FullBath
# GarageArea
# GarageCars
# GarageYrBlt
# GrLivArea
# HalfBath
# OverallQual
# SalePrice
# TotRmsAbvGrd
# TotalBsmtSF
# YearBuilt
# YearRemodAdd

# %%
#Pair plot for distribution and density
import seaborn as sns

# Assuming the dataset is named "df1"
numericalVariables = df1.select_dtypes(include=['int64', 'float64'])

# Create a pair plot
sns.pairplot(numericalVariables, kind='hist', diag_kind='kde')
plt.show()
# Out:
# /Users/raghavsharma/anaconda3/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
file_path = "categorical_variables.csv"

# Read the CSV file into a DataFrame
df2 = pd.read_csv(file_path)

# Perform operations on the df2 DataFrame as needed
# ...

#Missing value treatment - 

#1) Dropping missing values - we can use dropna() for this:

dropMissingValues=df2.dropna()
print(dropMissingValues)

#2)Filling missing values - we can use fillna() for this:

fillMissingValues=df2.fillna("Test") #Fill the missing value with Test

#print(fillMissingValues) #both are printed for examplatory purposes
# Out:
# Empty DataFrame
# Columns: [MSZoning, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinType2, Heating, HeatingQC, CentralAir, Electrical, KitchenQual, Functional, FireplaceQu, GarageType, GarageFinish, GarageQual, GarageCond, PavedDrive, PoolQC, Fence, MiscFeature, SaleType, SaleCondition]
# Index: []
#
# [0 rows x 43 columns]
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave  Test      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave  Test      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave  Test      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave  Test      IR1         Lvl    AllPub    Corner       Gtl
# ...

# %%
#3 - Forward fill and backward fill

# Fill missing values with a specific value
dfForwardFilled = df2.fillna('Unknown') #filling the missing values with 'Unknown'

# Backward fill (bfill) missing values
dfBackwardFilled = df2.bfill()

# Print the filled DataFrame
print("Filled DataFrame:")
print(dfForwardFilled)

# Print the DataFrame with backward-filled missing values
print("Backward-filled DataFrame:")
print(dfBackwardFilled)
# Out:
# Backward-filled DataFrame:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave  Grvl      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave  Grvl      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave  Grvl      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave  Grvl      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 1455       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
# ...

# %%
#Interpolate method only works for the Numerical dtype.

#Masking

# Filter rows with missing values
missingValues2 = df2[df2.isnull()]

#Print the filtered DataFrame
print("Rows with Missing Values:")
print(missingValues1)
# Out:
# Rows with Missing Values:
#       Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0    NaN         NaN          NaN      NaN          NaN          NaN
# 1    NaN         NaN          NaN      NaN          NaN          NaN
# 2    NaN         NaN          NaN      NaN          NaN          NaN
# 3    NaN         NaN          NaN      NaN          NaN          NaN
# 4    NaN         NaN          NaN      NaN          NaN          NaN
# ...   ..         ...          ...      ...          ...          ...
# 1455 NaN         NaN          NaN      NaN          NaN          NaN
# 1456 NaN         NaN          NaN      NaN          NaN          NaN
# 1457 NaN         NaN          NaN      NaN          NaN          NaN
# 1458 NaN         NaN          NaN      NaN          NaN          NaN
# 1459 NaN         NaN          NaN      NaN          NaN          NaN
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  \
# ...

# %%
import seaborn as sns

# Assuming the dataset is named "df"
# Assuming the variables of interest are "variable1" and "variable2"
sns.countplot(x='LotShape', hue='LandContour', data=df2)
plt.show()

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Create an empty dictionary to store the frequency count tables
frequency_count_tables = {}

# Loop through each categorical variable
categorical_variables = ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
                         'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
                         'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual',
                         'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
                         'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
                         'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
                         'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# Set the significance level (alpha)
alpha = 0.05

# Create an empty list to store significant variables
significantCategoricalVariables = []

for variable in categorical_variables:
    # Create a contingency table for each variable
    contingency_table = pd.crosstab(df2[variable], df2['MSZoning'])
    
    # Perform the chi-square test
    chi2, p_value, dof, expected = chi2_contingency(contingency_table)
    
    # Check if the p-value is less than alpha
    if p_value < alpha:
        significantCategoricalVariables.append(variable)

# Print the list of significant variables
print("Significant Variables:")
print(significantCategoricalVariables)
# Out:
# Significant Variables:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition']

# %%
# Concatenate the significant categorical and numerical variables
df3 = pd.concat([categoricalVariables[significantCategoricalVariables], numericalVariables[significantNumericalVariables]], axis=1)
#combinedData is a new dataset that we have named df3
# Print the combined dataset
print("Combined Dataset:")
print(df3)
df3.to_csv("combinedDataset.csv", index=False)
# Out:
# Combined Dataset:
#      MSZoning Street Alley LotShape LandContour LotConfig LandSlope  \
# 0          RL   Pave   NaN      Reg         Lvl    Inside       Gtl
# 1          RL   Pave   NaN      Reg         Lvl       FR2       Gtl
# 2          RL   Pave   NaN      IR1         Lvl    Inside       Gtl
# 3          RL   Pave   NaN      IR1         Lvl    Corner       Gtl
# 4          RL   Pave   NaN      IR1         Lvl       FR2       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...
# 1455       RL   Pave   NaN      Reg         Lvl    Inside       Gtl
# 1456       RL   Pave   NaN      Reg         Lvl    Inside       Gtl
# 1457       RL   Pave   NaN      Reg         Lvl    Inside       Gtl
# 1458       RL   Pave   NaN      Reg         Lvl    Inside       Gtl
# 1459       RL   Pave   NaN      Reg         Lvl    Inside       Gtl
#
#      Neighborhood Condition1 Condition2  ... GarageCars GarageYrBlt GrLivArea  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Specify the columns to include in the box plot
columns = ['GrLivArea', 'TotalBsmtSF', 'SalePrice','GarageCars','GarageYrBlt','GrLivArea','HalfBath','HalfBath','HalfBath','OverallQual','SalePrice','TotRmsAbvGrd','TotalBsmtSF','YearBuilt','YearRemodAdd']

# Create a box plot for the specified columns
plt.figure(figsize=(10, 6))
plt.boxplot(df3[columns].values)
plt.title("Box Plot of Variables")
plt.xticks(rotation=90)
plt.show()

#all the data points outside of the whiskers can be taken as potential outliers
